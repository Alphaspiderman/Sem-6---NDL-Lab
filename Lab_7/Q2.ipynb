# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as skdata
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers

# %%
x, y = skdata.load_iris(as_frame=True, return_X_y=True)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

y_train_encoded = to_categorical(y_train, num_classes=3)
y_test_encoded = to_categorical(y_test, num_classes=3)

# %%
model = keras.Sequential(
    [
        layers.Dense(128, activation="relu"),
        layers.Dense(3, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
)

# %%
history = model.fit(x_train, y_train_encoded, validation_data=(x_test, y_test_encoded), epochs=10)

plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='test accuracy')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.3419 - loss: 1.3475 - val_accuracy: 0.4000 - val_loss: 1.1941
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5058 - loss: 1.0868 - val_accuracy: 0.6333 - val_loss: 0.9859
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7104 - loss: 0.9609 - val_accuracy: 0.7000 - val_loss: 0.8941
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6125 - loss: 0.9099 - val_accuracy: 0.7000 - val_loss: 0.8560
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6444 - loss: 0.8570 - val_accuracy: 0.7000 - val_loss: 0.8202
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6085 - loss: 0.8578 - val_accuracy: 0.7667 - val_loss: 0.7822
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7398 - loss: 0.7814 - val_accuracy: 0.8333 - val_loss: 0.7427
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7977 - loss: 0.7484 - val_accuracy: 0.9000 - val_loss: 0.7117
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8640 - loss: 0.7108 - val_accuracy: 0.9000 - val_loss: 0.6793
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8660 - loss: 0.6786 - val_accuracy: 0.8333 - val_loss: 0.6513
